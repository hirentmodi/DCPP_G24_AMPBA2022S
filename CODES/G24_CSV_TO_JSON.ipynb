# %%
import pandas as pd
df = pd.read_csv ('G24_PC_D.csv')
df
# Out:
#               Key  Dist Code  Year  State Code    State Name       Dist Name  \
# 0         1199014          1  1990          14  Chhattisgarh            Durg
# 1         1199114          1  1991          14  Chhattisgarh            Durg
# 2         1199214          1  1992          14  Chhattisgarh            Durg
# 3         1199314          1  1993          14  Chhattisgarh            Durg
# 4         1199414          1  1994          14  Chhattisgarh            Durg
# ...           ...        ...   ...         ...           ...             ...
# 13960  2119201720       2119  2017          20     Telangana        Janagaon
# 13961  2120201620       2120  2016          20     Telangana  Warangal Urban
# 13962  2120201720       2120  2017          20     Telangana  Warangal Urban
# 13963  2121201620       2121  2016          20     Telangana     Mahabubabad
# 13964  2121201720       2121  2017          20     Telangana     Mahabubabad
#
# ...

# %%
df.to_json ('G24_PC_D.json')
