# %%
import pandas as  pd
df = pd.read_csv('G24_MASTER_S.csv', low_memory=False)

# %%
import sweetviz as sv
#analyzing the dataset
advert_report = sv.analyze(df,pairwise_analysis="on")
#display the report
advert_report.show_html('G24_MASTER_S.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
