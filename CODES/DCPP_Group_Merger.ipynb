# %%
import mitosheet

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-bea2b846-df33-48ac-9044-23d250e002a0", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-bea2b846-df33-48ac-9044-23d250e002a0') # Let Mito know which analysis is being run

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\1.csv
import pandas as pd
df_1_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\1.csv')

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\2.csv
import pandas as pd
df_2_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\2.csv')

# Merged df_1_csv and df_2_csv
temp_df = df_2_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_2_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df_1_csv.merge(df_2_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df_1_csv', '_df_2_csv'])

# Deleted dataframe df_1_csv
del df_1_csv

# Deleted dataframe df_2_csv
del df_2_csv

# Renamed df3 to df12
df12 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\3.csv
import pandas as pd
df_3_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\3.csv')

# Merged df12 and df_3_csv
temp_df = df_3_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_3_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df12.merge(df_3_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12', '_df_3_csv'])

# Deleted dataframe df12
del df12

# Deleted dataframe df_3_csv
del df_3_csv

# Renamed df3 to df123
df123 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\4.csv
import pandas as pd
df_4_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\4.csv')

# Merged df123 and df_4_csv
temp_df = df_4_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_4_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df123.merge(df_4_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123', '_df_4_csv'])

# Deleted dataframe df123
del df123

# Deleted dataframe df_4_csv
del df_4_csv

# Renamed df3 to df1234
df1234 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\5.csv
import pandas as pd
df_5_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\5.csv')

# Merged df1234 and df_5_csv
temp_df = df_5_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_5_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df1234.merge(df_5_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234', '_df_5_csv'])

# Deleted dataframe df1234
del df1234

# Deleted dataframe df_5_csv
del df_5_csv

# Renamed df3 to df12345
df12345 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\6.csv
import pandas as pd
df_6_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\6.csv')

# Merged df12345 and df_6_csv
temp_df = df_6_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_6_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df12345.merge(df_6_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345', '_df_6_csv'])

# Deleted dataframe df12345
del df12345

# Deleted dataframe df_6_csv
del df_6_csv

# Renamed df3 to df123456
df123456 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\7.csv
import pandas as pd
df_7_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\7.csv')

# Merged df123456 and df_7_csv
temp_df = df_7_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_7_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df123456.merge(df_7_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123456', '_df_7_csv'])

# Deleted dataframe df123456
del df123456

# Deleted dataframe df_7_csv
del df_7_csv

# Renamed df3 to df1234567
df1234567 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\8.csv
import pandas as pd
df_8_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\8.csv')

# Merged df1234567 and df_8_csv
temp_df = df_8_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_8_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df1234567.merge(df_8_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567', '_df_8_csv'])

# Deleted dataframe df1234567
del df1234567

# Deleted dataframe df_8_csv
del df_8_csv

# Renamed df3 to df12345678
df12345678 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\10.csv
import pandas as pd
df_10_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\10.csv')

# Merged df12345678 and df_10_csv
temp_df = df_10_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_10_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df12345678.merge(df_10_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678', '_df_10_csv'])

# Deleted dataframe df12345678
del df12345678

# Deleted dataframe df_10_csv
del df_10_csv

# Renamed df3 to df1234567810
df1234567810 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\13.csv
import pandas as pd
df_13_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\13.csv')

# Merged df1234567810 and df_13_csv
temp_df = df_13_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_13_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df1234567810.merge(df_13_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810', '_df_13_csv'])

# Deleted dataframe df1234567810
del df1234567810

# Deleted dataframe df_13_csv
del df_13_csv

# Renamed df3 to df123456781013
df123456781013 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\14.csv
import pandas as pd
df_14_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\14.csv')

# Merged df123456781013 and df_14_csv
temp_df = df_14_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_14_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df123456781013.merge(df_14_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123456781013', '_df_14_csv'])

# Deleted dataframe df123456781013
del df123456781013

# Deleted dataframe df_14_csv
del df_14_csv

# Renamed df3 to df12345678101314
df12345678101314 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\15.csv
import pandas as pd
df_15_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\15.csv')

# Merged df12345678101314 and df_15_csv
temp_df = df_15_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_15_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df12345678101314.merge(df_15_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678101314', '_df_15_csv'])

# Deleted dataframe df12345678101314
del df12345678101314

# Deleted dataframe df_15_csv
del df_15_csv

# Renamed df3 to df1234567810131415
df1234567810131415 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\16.csv
import pandas as pd
df_16_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\16.csv')

# Merged df1234567810131415 and df_16_csv
temp_df = df_16_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_16_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df1234567810131415.merge(df_16_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810131415', '_df_16_csv'])

# Deleted dataframe df1234567810131415
del df1234567810131415

# Deleted dataframe df_16_csv
del df_16_csv

# Renamed df3 to df123456781013141516
df123456781013141516 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\17.csv
import pandas as pd
df_17_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\17.csv')

# Merged df123456781013141516 and df_17_csv
temp_df = df_17_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_17_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df3 = df123456781013141516.merge(df_17_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123456781013141516', '_df_17_csv'])

# Deleted dataframe df123456781013141516
del df123456781013141516

# Deleted dataframe df_17_csv
del df_17_csv

# Renamed df3 to df12345678101314151617
df12345678101314151617 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\18.csv
import pandas as pd
df_18_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\18.csv')

# Merged df12345678101314151617 and df_18_csv
temp_df = df_18_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_18_csv_tmp = temp_df.drop(['Dist Code'], axis=1)
df3 = df12345678101314151617.merge(df_18_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678101314151617', '_df_18_csv'])

# Merged df12345678101314151617 and df_18_csv
temp_df = df_18_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_18_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df4 = df12345678101314151617.merge(df_18_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678101314151617', '_df_18_csv'])

# Deleted dataframe df12345678101314151617
del df12345678101314151617

# Deleted dataframe df_18_csv
del df_18_csv

# Deleted dataframe df3
del df3

# Renamed df4 to df1234567810131415161718
df1234567810131415161718 = df4

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\19.csv
import pandas as pd
df_19_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\19.csv')

# Merged df1234567810131415161718 and df_19_csv
temp_df = df_19_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_19_csv_tmp = temp_df.drop(['Dist Code'], axis=1)
df3 = df1234567810131415161718.merge(df_19_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810131415161718', '_df_19_csv'])

# Merged df1234567810131415161718 and df_19_csv
temp_df = df_19_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_19_csv_tmp = temp_df.drop(['State Code', 'Year', 'State Name', 'Dist Name', 'Dist Code'], axis=1)
df4 = df1234567810131415161718.merge(df_19_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810131415161718', '_df_19_csv'])

# Deleted dataframe df1234567810131415161718
del df1234567810131415161718

# Deleted dataframe df_19_csv
del df_19_csv

# Deleted dataframe df3
del df3

# Renamed df4 to df123456781013141516171819
df123456781013141516171819 = df4

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\21.csv
import pandas as pd
df_21_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\21.csv')

# Merged df123456781013141516171819 and df_21_csv
temp_df = df_21_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_21_csv_tmp = temp_df.drop(['State  code'], axis=1)
df3 = df123456781013141516171819.merge(df_21_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123456781013141516171819', '_df_21_csv'])

# Merged df123456781013141516171819 and df_21_csv
temp_df = df_21_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_21_csv_tmp = temp_df.drop(['District code', 'State  code', ' Year ', 'District name', 'State name'], axis=1)
df4 = df123456781013141516171819.merge(df_21_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123456781013141516171819', '_df_21_csv'])

# Deleted dataframe df123456781013141516171819
del df123456781013141516171819

# Deleted dataframe df_21_csv
del df_21_csv

# Deleted dataframe df3
del df3

# Renamed df4 to df12345678101314151617181921
df12345678101314151617181921 = df4

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\23.csv
import pandas as pd
df_23_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\23.csv')

# Merged df12345678101314151617181921 and df_23_csv
temp_df = df_23_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_23_csv_tmp = temp_df.drop(['District code', 'State code', ' Year', 'District name', 'State name'], axis=1)
df3 = df12345678101314151617181921.merge(df_23_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678101314151617181921', '_df_23_csv'])

# Deleted dataframe df12345678101314151617181921
del df12345678101314151617181921

# Deleted dataframe df_23_csv
del df_23_csv

# Renamed df3 to df1234567810131415161718192123
df1234567810131415161718192123 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\24.csv
import pandas as pd
df_24_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\24.csv')

# Merged df1234567810131415161718192123 and df_24_csv
temp_df = df_24_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_24_csv_tmp = temp_df.drop([' State', ' State Code', ' District', ' Year', ' District code'], axis=1)
df3 = df1234567810131415161718192123.merge(df_24_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810131415161718192123', '_df_24_csv'])

# Deleted dataframe df1234567810131415161718192123
del df1234567810131415161718192123

# Deleted dataframe df_24_csv
del df_24_csv

# Renamed df3 to df123456781013141516171819212324
df123456781013141516171819212324 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\25.csv
import pandas as pd
df_25_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\25.csv')

# Merged df123456781013141516171819212324 and df_25_csv
temp_df = df_25_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_25_csv_tmp = temp_df.drop(['Unnamed: 26', ' State code', ' District name', ' Year', ' District code', ' State name'], axis=1)
df3 = df123456781013141516171819212324.merge(df_25_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df123456781013141516171819212324', '_df_25_csv'])

# Deleted dataframe df123456781013141516171819212324
del df123456781013141516171819212324

# Deleted dataframe df_25_csv
del df_25_csv

# Renamed df3 to df12345678101314151617181921232425
df12345678101314151617181921232425 = df3

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\27.csv
import pandas as pd
df_27_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\27.csv')

# Merged df12345678101314151617181921232425 and df_27_csv
temp_df = df_27_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_27_csv_tmp = temp_df.drop([' State Code'], axis=1)
df3 = df12345678101314151617181921232425.merge(df_27_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678101314151617181921232425', '_df_27_csv'])

# Merged df12345678101314151617181921232425 and df_27_csv
temp_df = df_27_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_27_csv_tmp = temp_df.drop([' District name', ' State Code', ' Year', ' District code', ' State name'], axis=1)
df4 = df12345678101314151617181921232425.merge(df_27_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df12345678101314151617181921232425', '_df_27_csv'])

# Deleted dataframe df12345678101314151617181921232425
del df12345678101314151617181921232425

# Deleted dataframe df_27_csv
del df_27_csv

# Deleted dataframe df3
del df3

# Renamed df4 to df1234567810131415161718192123242527
df1234567810131415161718192123242527 = df4

# Imported C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\28.csv
import pandas as pd
df_28_csv = pd.read_csv(r'C:\Users\Hiren Modi\Desktop\DCPP_Group_Assignment\28.csv')

# Merged df1234567810131415161718192123242527 and df_28_csv
temp_df = df_28_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_28_csv_tmp = temp_df.drop(['  State Code', '  State name', '  District code', '  Year'], axis=1)
df4 = df1234567810131415161718192123242527.merge(df_28_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810131415161718192123242527', '_df_28_csv'])

# Merged df1234567810131415161718192123242527 and df_28_csv
temp_df = df_28_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_28_csv_tmp = temp_df.drop(['  State Code', '  District name', '  Year', '  State name', '  District code'], axis=1)
df5 = df1234567810131415161718192123242527.merge(df_28_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df1234567810131415161718192123242527', '_df_28_csv'])

# Deleted dataframe df1234567810131415161718192123242527
del df1234567810131415161718192123242527

# Deleted dataframe df_28_csv
del df_28_csv

# Deleted dataframe df3
del df3

# Deleted dataframe df4
del df4

# Renamed df5 to df123456781013141516171819212324252728
df123456781013141516171819212324252728 = df5

  
# MITO CODE END (DO NOT EDIT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6e940362808e> in <module>
#     421
#     422 # Deleted dataframe df3
# --> 423 del df3
#     424
#     425 # Deleted dataframe df4
#
# NameError: name 'df3' is not defined

# %%
df5.to_csv("Final_df28.csv")
