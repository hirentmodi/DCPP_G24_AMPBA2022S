# %%
import mitosheet

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-dffebb96-6f89-44dc-a43d-1a8081d40726", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-6e15bf71-05d6-411e-bf4b-4c43d4f85525') # Let Mito know which analysis is being run

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/3a.csv
import pandas as pd
df_3a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/3a.csv')

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/1a.csv
import pandas as pd
df_1a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/1a.csv')

# Merged df_3a_csv and df_1a_csv
temp_df = df_1a_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_1a_csv_tmp = temp_df.drop([' District name', '  Year ', ' District code', ' State  code', ' State name'], axis=1)
df3 = df_3a_csv.merge(df_1a_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df_3a_csv', '_df_1a_csv'])

# Deleted dataframe df_3a_csv
del df_3a_csv

# Deleted dataframe df_1a_csv
del df_1a_csv

# Renamed df3 to df
df = df3

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/6a.csv
import pandas as pd
df_6a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/6a.csv')

# Merged df and df_6a_csv
temp_df = df_6a_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_6a_csv_tmp = temp_df.drop(['District code', 'State', 'State Code', 'District', 'Year'], axis=1)
df3 = df.merge(df_6a_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df', '_df_6a_csv'])

# Deleted dataframe df
del df

# Deleted dataframe df_6a_csv
del df_6a_csv

# Renamed df3 to df
df = df3

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/13a.csv
import pandas as pd
df_13a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/13a.csv')

# Merged df and df_13a_csv
temp_df = df_13a_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_13a_csv_tmp = temp_df.drop(['District name', 'District code', 'State name', 'State Code', 'Year'], axis=1)
df3 = df.merge(df_13a_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df', '_df_13a_csv'])

# Deleted dataframe df
del df

# Deleted dataframe df_13a_csv
del df_13a_csv

# Renamed df3 to df
df = df3

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/14a.csv
import pandas as pd
df_14a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/14a.csv')

# Merged df and df_14a_csv
temp_df = df_14a_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
df_14a_csv_tmp = temp_df.drop(['District name', 'District code', 'State name', 'State Code', 'Year'], axis=1)
df3 = df.merge(df_14a_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df', '_df_14a_csv'])

# Deleted dataframe df
del df

# Deleted dataframe df_14a_csv
del df_14a_csv

# Renamed df3 to df
df = df3

  
# MITO CODE END (DO NOT EDIT)
