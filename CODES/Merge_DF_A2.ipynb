# %%
import mitosheet

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-22874f97-6723-44fc-a521-df7078b2526e", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-22874f97-6723-44fc-a521-df7078b2526e') # Let Mito know which analysis is being run

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/dfa_merged1a.csv
import pandas as pd
dfa_merged1a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/dfa_merged1a.csv')

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/dfa_merged2a.csv
import pandas as pd
dfa_merged2a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/dfa_merged2a.csv')

# Merged dfa_merged1a_csv and dfa_merged2a_csv
temp_df = dfa_merged2a_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
dfa_merged2a_csv_tmp = temp_df.drop(['Row Labels'], axis=1)
df3 = dfa_merged1a_csv.merge(dfa_merged2a_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_dfa_merged1a_csv', '_dfa_merged2a_csv'])

# Deleted dataframe dfa_merged1a_csv
del dfa_merged1a_csv

# Deleted dataframe dfa_merged2a_csv
del dfa_merged2a_csv

# Renamed df3 to df
df = df3

# Imported /Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/dfa_merged3a.csv
import pandas as pd
dfa_merged3a_csv = pd.read_csv(r'/Users/hirenmodi/Desktop/DCPP Final/DCPP_Group_Assignment/dfa_merged3a.csv')

# Merged df and dfa_merged3a_csv
temp_df = dfa_merged3a_csv.drop_duplicates(subset='Key') # Remove duplicates so lookup merge only returns first match
dfa_merged3a_csv_tmp = temp_df.drop(['Row Labels'], axis=1)
df3 = df.merge(dfa_merged3a_csv_tmp, left_on=['Key'], right_on=['Key'], how='left', suffixes=['_df', '_dfa_merged3a_csv'])

# Deleted dataframe df
del df

# Deleted dataframe dfa_merged3a_csv
del dfa_merged3a_csv

# Renamed df3 to df
df = df3

# Renamed df to dfa_merged_pivoted
dfa_merged_pivoted = df

  
# MITO CODE END (DO NOT EDIT)
